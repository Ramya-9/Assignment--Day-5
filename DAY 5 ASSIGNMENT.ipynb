# %%
def check_prime(n):
  i = 2
  p = 1 
  
  while i < n:
   if n%i == 0:
      p = 0
      break
   i = i+1
 
  return p
 
x = int(input("Enter your number : "))
p = check_prime(x)
 
if p==1:
   print("Your Number is prime !")
else:
   print("Your Number is not prime !")
# Out:
# Enter your number : 9371
# Your Number is prime !
